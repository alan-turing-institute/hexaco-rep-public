# %% [markdown]
# # PCA for 8 Factor Solution (PopProfessional)

# %%
import pandas as pd
import numpy as np
from support.pca_support import perform_pca

n_factors = 8
ipsatized_data = pd.read_csv('data/popp_ipsatised_results.csv', index_col=0)
results_file = 'intermediate/loadings_popp_8.csv'
results_file = perform_pca('data/popp_ipsatised_results.csv', n_factors, 'intermediate/loadings_popp_8.csv')
loadings = pd.read_csv(results_file, index_col=0)
loadings.columns = [f'Factor{x}' for x in range(1, n_factors+1)]
print(f"loadings shape = {loadings.shape}")
# Out:
# Args: input_file= data/popp_ipsatised_results.csv , n_factors= 8 , rotation_method promax
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined.
# Chi square is based upon observed residuals.
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined for the null model either.
# The Chi square is thus based upon observed correlations.
# loadings shape = (1666, 8)

# %%
explained_variance = np.sum(loadings**2, axis=0)
variances = [x/len(loadings)*100 for x in explained_variance]
print("variances: "+", ".join([f"{x:.2f}%" for x in variances])+ f", cumulative: {sum(variances):.2f}%")
# Out:
# variances: 3.22%, 2.54%, 2.48%, 2.29%, 1.90%, 1.51%, 1.22%, 0.89%, cumulative: 16.05%

# %%
from support.pca_support import get_highest_loadings
highest_loadings, pp = get_highest_loadings(30, loadings)
agent_loadings_df = pd.DataFrame(highest_loadings)
labels_factors = ['Unconscientiousness', 'Introversion', 'Unconciliatory', 
                  'Conventional', 'Extravagant', 'Emotionality', 
                  'Heroic', 'Unscholarly']
pp.columns = [pp.columns[x]+'('+labels_factors[x]+')' for x in range(len(pp.columns))]
pp
# Out:
#    Factor1(Unconscientiousness)  Factor2(Introversion)  \
# 0            unmethodical(0.74)  undemonstrative(0.60)
# 1            unsystematic(0.73)          unvocal(0.60)
# 2               haphazard(0.73)      untalkative(0.58)
# 3                planless(0.70)     ungregarious(0.58)
# 4          scatterbrained(0.66)      unexpansive(0.58)
# 5      overconscientious(-0.66)        seclusive(0.57)
# 6              unpunctual(0.66)         taciturn(0.57)
# 7                careless(0.65)         nonvocal(0.54)
# 8           overdiligent(-0.65)  uncommunicative(0.54)
# 9             hit-or-miss(0.65)        hermitish(0.54)
# 10           disorganized(0.64)        reclusive(0.54)
# 11               heedless(0.63)          asocial(0.53)
# 12          undisciplined(0.62)          distant(0.53)
# 13             unthorough(0.61)        withdrawn(0.53)
# 14         undeliberative(0.61)         detached(0.53)
# 15             undiligent(0.60)      unconfiding(0.52)
# 16                    lax(0.60)     unpersonable(0.52)
# 17           inconsistent(0.60)    close-mouthed(0.52)
# 18             digressive(0.60)         unsocial(0.52)
# 19          absent-minded(0.60)         reserved(0.51)
# 20               planful(-0.59)  uncompanionable(0.51)
# 21             unexacting(0.58)       unsociable(0.51)
# 22             unvigilant(0.57)      withdrawing(0.51)
# 23             organized(-0.57)        dissocial(0.51)
# 24           distractible(0.56)       unspeaking(0.51)
# 25                  messy(0.56)            aloof(0.51)
# 26               orderly(-0.56)     unsolicitous(0.50)
# 27              unheedful(0.56)       impersonal(0.49)
# 28              punctual(-0.55)        uncourtly(0.49)
# 29            meticulous(-0.55)      standoffish(0.48)
#
#    Factor3(Unconciliatory)    Factor4(Conventional)   Factor5(Extravagant)  \
# 0            brusque(0.58)       conventional(0.68)   unextravagant(-0.55)
# 1           womanly(-0.58)        traditional(0.60)      acquisitive(0.53)
# 2         bullheaded(0.56)       conservative(0.60)           lavish(0.53)
# 3     unconciliatory(0.56)             sedate(0.59)  unostentatious(-0.52)
# 4         hard-nosed(0.55)         changeless(0.57)    untheatrical(-0.50)
# 5              blunt(0.55)      old-fashioned(0.56)    opportunistic(0.50)
# 6         hardheaded(0.52)         unchanging(0.55)      extravagant(0.49)
# 7      sharp-tongued(0.51)    unconventional(-0.55)        exclusive(0.47)
# 8        unforgiving(0.50)         nonvariant(0.54)    quiet-spoken(-0.46)
# 9              harsh(0.49)        predictable(0.52)            showy(0.46)
# 10         overharsh(0.49)       strait-laced(0.52)      unassuming(-0.46)
# 11   unaccommodating(0.49)      unadventurous(0.52)       uncunning(-0.46)
# 12         unbending(0.49)        inexcitable(0.51)  unbusinesslike(-0.45)
# 13         pigheaded(0.49)          unvarying(0.50)     unpresuming(-0.45)
# 14         obstinate(0.49)   unconstrainable(-0.50)     unexplosive(-0.45)
# 15             stern(0.48)          restless(-0.49)      extroverted(0.45)
# 16         ladylike(-0.48)          variable(-0.49)        rivalrous(0.45)
# 17             testy(0.48)        unexcitable(0.48)     ingratiatory(0.44)
# 18     uncomplaisant(0.48)       venturesome(-0.47)          modest(-0.44)
# 19          abrasive(0.47)      unprogressive(0.47)          earthy(-0.44)
# 20             manly(0.47)       unchangeable(0.46)           dapper(0.44)
# 21              curt(0.47)      inconfinable(-0.45)            suave(0.43)
# 22          indocile(0.46)        unventurous(0.45)       unhurried(-0.43)
# 23         masculine(0.46)        unadaptable(0.44)         debonair(0.43)
# 24          hardened(0.46)  ultraconservative(0.44)       chitchatty(0.43)
# 25          stubborn(0.46)         venturous(-0.43)            slick(0.42)
# 26        inflexible(0.45)       unmodifiable(0.43)          rugged(-0.42)
# 27       unagreeable(0.45)            uneager(0.43)          bullish(0.42)
# 28        forgiving(-0.45)         invariable(0.42)   down-to-earth(-0.42)
# 29     ultracritical(0.45)        unstirrable(0.42)             chic(0.41)
#
#      Factor6(Emotionality)         Factor7(Heroic)      Factor8(Unscholarly)
# 0     unsentimental(-0.58)          finicky(-0.59)            bookish(-0.66)
# 1     unbusinesslike(0.52)         artistic(-0.52)           unbookish(0.65)
# 2       calculating(-0.52)         fanciful(-0.50)     unphilosophical(0.56)
# 3     supersensitive(0.48)            fussy(-0.49)           literary(-0.55)
# 4   ultrasentimental(0.47)             chic(-0.48)         unscholarly(0.53)
# 5      overemotional(0.46)   overfastidious(-0.48)        overbookish(-0.50)
# 6            fretful(0.44)     ultrarefined(-0.43)          scholarly(-0.50)
# 7        sentimental(0.44)            heroic(0.43)       overstudious(-0.47)
# 8       thin-skinned(0.44)        designful(-0.42)     philosophizing(-0.44)
# 9     thick-skinned(-0.44)         overneat(-0.42)          unliterary(0.44)
# 10     businesslike(-0.44)            picky(-0.40)  ultraintellectual(-0.44)
# 11         emotional(0.44)        whimsical(-0.39)          political(-0.44)
# 12    hypersensitive(0.43)         crusading(0.39)           studious(-0.43)
# 13     uncalculating(0.43)     cosmopolitan(-0.39)       encyclopedic(-0.42)
# 14      soft-shelled(0.43)           poetic(-0.38)              wordy(-0.41)
# 15      tenderminded(0.42)          elegant(-0.38)          well-read(-0.40)
# 16       hard-nosed(-0.41)   discriminative(-0.38)      philosophical(-0.39)
# 17       melancholic(0.40)         abstract(-0.37)      inquisitorial(-0.38)
# 18      mechanistic(-0.40)   overparticular(-0.37)         unpolitical(0.38)
# 19        overcaring(0.39)           valiant(0.37)        long-winded(-0.30)
# 20    self-conscious(0.38)          valorous(0.37)         unskeptical(0.30)
# 21      competitory(-0.38)      overrefined(-0.36)           cerebral(-0.30)
# 22            tender(0.38)  ultrafastidious(-0.36)          unstudious(0.29)
# 23     oversensitive(0.38)          refined(-0.36)       unquestioning(0.27)
# 24            touchy(0.38)  overimaginative(-0.35)           careworn(-0.27)
# 25            earthy(0.37)        unartistic(0.35)        overcurious(-0.27)
# 26       calculable(-0.37)      uncontriving(0.34)          ineloquent(0.26)
# 27            poetic(0.37)           urbane(-0.34)               nosy(-0.26)
# 28     nonspiritual(-0.36)      unpleasable(-0.34)           eloquent(-0.26)
# 29     tough-minded(-0.36)           scrappy(0.34)             verbal(-0.26)

# %%
from support.cronbach_alpha import calc_cronbachs_alpha as cronbach_alpha
alphas = []
for dim in highest_loadings:
    cols = highest_loadings[dim]
    df_ = ipsatized_data[cols.index]
    alpha = cronbach_alpha(df_)
    alphas.append(alpha)
print("Cronbach's Alpha: "+", ".join([f"{x:.2f}" for x in alphas]))
# Out:
# Cronbach's Alpha: 0.88, 0.98, 0.92, 0.85, -0.11, 0.39, 0.78, 0.58

# %%
from support.data_support import load_hexaco_data
from support.jaccard import calc_jaccard_with_hexaco
jaccards = calc_jaccard_with_hexaco(agent_loadings_df, load_hexaco_data())
highest_jaccards = list(zip(jaccards.index, jaccards.idxmax(axis=1), jaccards.max(axis=1)))
print("Highest Jaccard Similarities:")
[print(f" * {a} -> {b}, ({c:.3f})") for a, b, c in list(highest_jaccards)];
# Out:
# Highest Jaccard Similarities:
#  * Factor1 -> Conscientiousness, (0.150)
#  * Factor2 -> Extraversion, (0.105)
#  * Factor3 -> Emotionality, (0.063)
#  * Factor4 -> Openness, (0.050)
#  * Factor5 -> Honesty-Humility, (0.067)
#  * Factor6 -> Emotionality, (0.098)
#  * Factor7 -> Openness, (0.015)
#  * Factor8 -> Openness, (0.066)

# %%
from support.semantic_similarity import load_embedding_model, compute_similarity
model = load_embedding_model()
for i, m in enumerate(highest_loadings.keys()):
    # reduce terms to only those we know are in the model...
    ats = [x for x in highest_loadings[m].index if x in model]
    sim, matrix = compute_similarity(ats, model)
    print(f"Average similarity for {m}({labels_factors[i]}): {sim:.3f}")
# Out:
# Average similarity for Factor1(Unconscientiousness): 0.490
# Average similarity for Factor2(Introversion): 0.505
# Average similarity for Factor3(Unconciliatory): 0.557
# Average similarity for Factor4(Conventional): 0.501
# Average similarity for Factor5(Extravagant): 0.480
# Average similarity for Factor6(Emotionality): 0.463
# Average similarity for Factor7(Heroic): 0.471
# Average similarity for Factor8(Unscholarly): 0.466
