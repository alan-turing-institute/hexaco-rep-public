# %%
from results_template import generate_results

generate_results(10, 'PopCensus', 
                 'data/popc_ipsatised_results.csv', 
                 'intermediate/loadings_popc_10.csv',
                 ['Dishonesty', 'Disagreeableness', 'Introversion', 
                  'Unconscientiousness', 'Unheroic', 'Unscholarly', 
                  'Gendered-emotionality', 'Unsentimentality', 
                  'Insensitivity', 'Unartistic'])
# Out:
# ## PC & Results for PopCensus's 10 Solution.
# Args: input_file =  data/popc_ipsatised_results.csv n_factors = 10 rotation_method = promax
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined.
# Chi square is based upon observed residuals.
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined for the null model either.
# The Chi square is thus based upon observed correlations.
# Loadings shape = (1702, 10)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Factor1(Dishonesty)</th>
#       <th>Factor2(Disagreeableness)</th>
#       <th>Factor3(Introversion)</th>
#       <th>Factor4(Unconscientiousness)</th>
#       <th>Factor5(Unheroic)</th>
#       <th>Factor6(Unscholarly)</th>
#       <th>Factor7(Gendered-emotionality)</th>
#       <th>Factor8(Unsentimentality)</th>
#       <th>Factor9(Insensitivity)</th>
# ...
