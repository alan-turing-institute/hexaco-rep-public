# %%
from results_template import generate_results

generate_results(6, 'PopCensus', 
                 'data/popc_ipsatised_results.csv', 
                 'intermediate/loadings_popc_6.csv',
                 ['Dishonesty', 'Introversion', 'Unconventionality', 'Dominance', 
                  'Disagreeableness', 'Provincial'])
# Out:
# ## Performing PCA & displaying results for PopCensus's 6 solution.
# Args: input_file =  data/popc_ipsatised_results.csv n_factors = 6 rotation_method = promax
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined.
# Chi square is based upon observed residuals.
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined for the null model either.
# The Chi square is thus based upon observed correlations.
# Loadings shape = (1702, 6)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Factor1(Dishonesty)</th>
#       <th>Factor2(Introversion)</th>
#       <th>Factor3(Unconventionality)</th>
#       <th>Factor4(Dominance)</th>
#       <th>Factor5(Disagreeableness)</th>
#       <th>Factor6(Provincial)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>sly(0.91)</td>
# ...
