# %%
import pandas as pd
from matplotlib import pyplot as plt
from support.census_support import plot

df_professional = pd.read_json('data/pop_professional.json')
df_census = pd.read_json('data/pop_census.json')

plot(df_professional)
plot(df_census)
