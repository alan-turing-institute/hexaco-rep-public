# %% [markdown]
# # HEXACO-PI-R 100 Survey Results: Agents 'v' Humans

# %%
from support.hexaco_pi_r import *

files = {
    "GPT4": "data/hexaco-pi-r-responses-GPT-4.csv",
    "llama3.2": "data/hexaco-pi-r-responses-llama3.2.csv",
    "phi4": "data/hexaco-pi-r-responses-phi4.csv",
    "sonnet": "data/hexaco-pi-r-responses-sonnet.csv"
}

for model_name, responses in files.items():
    process_pir(model_name, responses)
# Out:
#                     mean     sd  alpha
# Honesty-Humility  3.9454 0.7431 0.9082
# Emotionality      2.9788 0.8764 0.8936
# Extraversion      3.4873 0.8363 0.9081
# Agreeableness     3.0772 0.8647 0.9108
# Conscientiousness 4.3119 0.7679 0.9336
# Openness          3.4155 0.7990 0.8176
#                     mean     sd   alpha
# Honesty-Humility  3.6083 0.8420  0.0993
# Emotionality      3.0700 0.9318 -0.1031
# Extraversion      3.0089 0.8330  0.0849
# Agreeableness     3.1335 0.8436 -0.0027
# Conscientiousness 3.2893 0.9480  0.3224
# Openness          3.3002 0.9195  0.1771
#                     mean     sd  alpha
# Honesty-Humility  3.9724 0.7325 0.8966
# Emotionality      2.9663 0.8168 0.8563
# Extraversion      3.6091 0.7716 0.8340
# Agreeableness     3.4091 0.9175 0.8825
# Conscientiousness 4.3091 0.7530 0.8829
# Openness          3.5714 0.7243 0.7627
#                     mean     sd  alpha
# Honesty-Humility  4.0510 0.8485 0.9283
# Emotionality      3.2700 0.8989 0.9129
# ...
