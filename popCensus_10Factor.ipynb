# %% [markdown]
# # PCA for 10 Factor Solution (PopCensus)

# %%
import pandas as pd
import numpy as np
from support.pca_support import perform_pca

n_factors = 10
ipsatized_data = pd.read_csv('data/popc_ipsatised_results.csv', index_col=0)
results_file = 'intermediate/loadings_popc_10.csv'
results_file = perform_pca('data/popc_ipsatised_results.csv', n_factors, 'intermediate/loadings_popc_10.csv')
loadings = pd.read_csv(results_file, index_col=0)
loadings.columns = [f'Factor{x}' for x in range(1, n_factors+1)]
print(f"loadings shape = {loadings.shape}")
# Out:
# Args: input_file= data/popc_ipsatised_results.csv , n_factors= 10 , rotation_method promax
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined.
# Chi square is based upon observed residuals.
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined for the null model either.
# The Chi square is thus based upon observed correlations.
# loadings shape = (1702, 10)

# %%
explained_variance = np.sum(loadings**2, axis=0)
variances = [x/len(loadings)*100 for x in explained_variance]
print("variances: "+", ".join([f"{x:.2f}%" for x in variances])+ f", cumulative: {sum(variances):.2f}%")
# Out:
# variances: 4.00%, 3.79%, 3.18%, 3.09%, 2.80%, 1.62%, 1.10%, 1.01%, 1.00%, 0.92%, cumulative: 22.51%

# %%
from support.pca_support import get_highest_loadings
highest_loadings, pp = get_highest_loadings(30, loadings)
agent_loadings_df = pd.DataFrame(highest_loadings)
labels_factors = ['Dishonesty', 'Disagreeableness', 'Introversion', 
                  'Unconscientiousness', 'Unheroic', 'Unscholarly', 
                  'Gendered-emotionality', 'Unsentimentality', 'Insensitivity', 
                  'Unartistic']
pp.columns = [pp.columns[x]+'('+labels_factors[x]+')' for x in range(len(pp.columns))]
pp
# Out:
#      Factor1(Dishonesty) Factor2(Disagreeableness)  Factor3(Introversion)  \
# 0              sly(0.94)       sharp-tongued(0.74)  uncommunicative(0.72)
# 1           sneaky(0.93)            abrasive(0.69)            aloof(0.71)
# 2        deceptive(0.93)        unforbearing(0.67)      untalkative(0.71)
# 3          devious(0.91)               harsh(0.66)        seclusive(0.69)
# 4       undevious(-0.90)           overharsh(0.66)     ungregarious(0.68)
# 5     undeceptive(-0.89)       argumentative(0.66)  uncompanionable(0.68)
# 6     manipulative(0.89)     unaccommodating(0.65)          distant(0.67)
# 7        deceitful(0.87)             caustic(0.65)         detached(0.67)
# 8      underhanded(0.86)         overbearing(0.65)        withdrawn(0.67)
# 9         uncandid(0.85)         unforgiving(0.64)         taciturn(0.67)
# 10      untrustful(0.85)      unconciliatory(0.62)      standoffish(0.66)
# 11    double-faced(0.84)        faultfinding(0.60)       unsociable(0.66)
# 12        scheming(0.84)               testy(0.60)     unaccessible(0.65)
# 13    unscrupulous(0.84)             peevish(0.59)          asocial(0.65)
# 14  double-tongued(0.84)             brusque(0.59)         unsocial(0.65)
# 15   untrustworthy(0.82)      good-tempered(-0.59)      withdrawing(0.65)
# 16   untransparent(0.82)         unagreeable(0.58)        reclusive(0.65)
# 17         evasive(0.82)          forgiving(-0.58)        dissocial(0.64)
# 18      incorrupt(-0.81)          intolerant(0.58)     unsolicitous(0.62)
# 19           cagey(0.80)        antagonistic(0.58)  undemonstrative(0.62)
# 20         roguish(0.79)        undiplomatic(0.57)        hermitish(0.62)
# 21     pretenseful(0.79)        cantankerous(0.57)       impersonal(0.62)
# 22  plain-dealing(-0.77)            ungentle(0.56)   communicative(-0.61)
# 23      suspicious(0.76)         reproachful(0.56)    close-mouthed(0.60)
# 24    exploitative(0.75)         forbearing(-0.56)     unpersonable(0.60)
# 25       dishonest(0.75)              crabby(0.56)       antisocial(0.59)
# 26         knavish(0.75)               bossy(0.56)          social(-0.59)
# 27       unethical(0.73)         high-handed(0.55)       unspeaking(0.59)
# 28  incorruptible(-0.73)           censorial(0.55)      accessible(-0.59)
# 29    self-seeking(0.72)           tolerant(-0.55)         nonvocal(0.59)
#
#    Factor4(Unconscientiousness)       Factor5(Unheroic)  \
# 0               overneat(-0.67)            unbold(0.69)
# 1      overconscientious(-0.60)     unadventurous(0.64)
# 2                   messy(0.60)      venturesome(-0.63)
# 3             hit-or-miss(0.59)              mild(0.62)
# 4          unbusinesslike(0.58)        venturous(-0.61)
# 5                planless(0.57)            sedate(0.61)
# 6            unmethodical(0.57)           fierce(-0.60)
# 7            unsystematic(0.56)           daring(-0.60)
# 8        ultrafastidious(-0.55)           hectic(-0.57)
# 9         overscrupulous(-0.54)            placid(0.56)
# 10               orderly(-0.54)         restless(-0.56)
# 11               unreined(0.53)  unconstrainable(-0.55)
# 12          overrigorous(-0.53)        audacious(-0.53)
# 13                 untidy(0.53)      adventurous(-0.53)
# 14          undisciplined(0.53)            fiery(-0.53)
# 15          overdiligent(-0.53)       inexcitable(0.52)
# 16           distractible(0.52)   irrestrainable(-0.52)
# 17              punctual(-0.52)       unventurous(0.50)
# 18              unheedful(0.52)          intense(-0.50)
# 19             stringent(-0.52)        untamable(-0.49)
# 20          strait-laced(-0.51)     lion-hearted(-0.49)
# 21               heedless(0.51)       overdaring(-0.49)
# 22                  tidy(-0.50)            gutsy(-0.49)
# 23             overrigid(-0.50)   unrestrainable(-0.49)
# 24         conscientious(-0.50)          unheroic(0.48)
# 25             unpunctual(0.50)       unexcitable(0.48)
# 26                    lax(0.50)      hot-blooded(-0.48)
# 27        overfastidious(-0.49)          dynamic(-0.48)
# 28               careless(0.49)         headlong(-0.47)
# 29       perfectionistic(-0.49)          scrappy(-0.47)
#
#         Factor6(Unscholarly) Factor7(Gendered-emotionality)  \
# 0            unbookish(0.71)                  womanly(1.07)
# 1          unscholarly(0.70)           gentlemanlike(-0.96)
# 2           unliterary(0.67)                 feminine(0.90)
# 3             bookish(-0.62)               masculine(-0.89)
# 4   ultraintellectual(-0.61)                   manly(-0.89)
# 5         overbookish(-0.60)                 ladylike(0.80)
# 6           scholarly(-0.58)                  virile(-0.77)
# 7      unphilosophical(0.56)              unmasculine(0.58)
# 8          unskeptical(0.55)                  rugged(-0.43)
# 9        overstudious(-0.55)                 maternal(0.43)
# 10           literary(-0.54)                vivacious(0.37)
# 11          unstudious(0.53)                   bubbly(0.33)
# 12           cerebral(-0.51)                sparkling(0.31)
# 13      inquisitorial(-0.50)           unbusinesslike(0.31)
# 14            homespun(0.49)                    perky(0.30)
# 15     philosophizing(-0.48)                 graceful(0.30)
# 16              rugged(0.47)                    sassy(0.30)
# 17           studious(-0.47)               voluptuous(0.29)
# 18          well-read(-0.46)                hardened(-0.29)
# 19              folksy(0.46)              unfeminine(-0.28)
# 20             brainy(-0.45)                emotional(0.28)
# 21      sophisticated(-0.44)                   demure(0.28)
# 22       unprovincial(-0.43)                  angelic(0.28)
# 23       encyclopedic(-0.41)              chivalrous(-0.28)
# 24           abstract(-0.41)                  elegant(0.28)
# 25        arbitrative(-0.39)                     chic(0.28)
# 26      philosophical(-0.39)                   dainty(0.27)
# 27           eloquent(-0.37)                 lamblike(0.27)
# 28          political(-0.37)            nonspiritual(-0.27)
# 29              earthy(0.37)                  girlish(0.26)
#
#    Factor8(Unsentimentality)   Factor9(Insensitivity)  Factor10(Unartistic)
# 0        unsentimental(0.53)           finicky(-0.51)   ultrarefined(-0.50)
# 1              earthy(-0.49)           fretful(-0.48)           chic(-0.50)
# 2            homespun(-0.49)             fussy(-0.45)         lavish(-0.49)
# 3      long-suffering(-0.39)       overnervous(-0.42)        refined(-0.45)
# 4          competitory(0.38)          worrying(-0.41)         dapper(-0.45)
# 5          mechanistic(0.38)           anxious(-0.37)        elegant(-0.45)
# 6         sentimental(-0.37)             tense(-0.36)    overrefined(-0.43)
# 7        tenderminded(-0.37)    overfastidious(-0.36)   unextravagant(0.43)
# 8            careworn(-0.37)       perturbable(-0.35)    extravagant(-0.41)
# 9      tender-hearted(-0.36)        compulsive(-0.35)   cosmopolitan(-0.41)
# 10              speedy(0.36)    supersensitive(-0.34)       polished(-0.41)
# 11           reverent(-0.36)      thick-skinned(0.33)       debonair(-0.39)
# 12             serene(-0.36)    self-punishing(-0.33)    overelegant(-0.38)
# 13             folksy(-0.35)  self-reproachful(-0.33)  sophisticated(-0.38)
# 14             tender(-0.34)   ultrafastidious(-0.33)      exclusive(-0.38)
# 15          spiritual(-0.34)      imperturbable(0.31)         urbane(-0.37)
# 16             poetic(-0.33)       high-strung(-0.31)        genteel(-0.34)
# 17         overcaring(-0.32)     self-critical(-0.31)    untheatrical(0.34)
# 18          sensitive(-0.32)            touchy(-0.31)       inelegant(0.34)
# 19        nonspiritual(0.32)          overneat(-0.31)      designful(-0.34)
# 20      gentle-minded(-0.32)      faultfinding(-0.31)       fanciful(-0.34)
# 21           maternal(-0.32)          artistic(-0.29)          suave(-0.33)
# 22          unartistic(0.32)      thin-skinned(-0.29)       overneat(-0.30)
# 23      old-fashioned(-0.30)       overintense(-0.29)          snoopy(0.30)
# 24       soft-hearted(-0.30)       overcurious(-0.29)          showy(-0.28)
# 25   ultrasentimental(-0.30)    hypersensitive(-0.29)          fussy(-0.28)
# 26         altruistic(-0.29)         unartistic(0.29)  unostentatious(0.28)
# 27         feelingful(-0.28)     oversensitive(-0.28)      unartistic(0.28)
# 28       dispassionate(0.28)    overscrupulous(-0.28)       artistic(-0.28)
# 29       humanitarian(-0.28)    overthoughtful(-0.28)       uncourtly(0.27)

# %%
from support.cronbach_alpha import calc_cronbachs_alpha as cronbach_alpha
alphas = []
for dim in highest_loadings:
    cols = highest_loadings[dim]
    df_ = ipsatized_data[cols.index]
    alpha = cronbach_alpha(df_)
    alphas.append(alpha)
print("Cronbach's Alpha: "+", ".join([f"{x:.2f}" for x in alphas]))
# Out:
# Cronbach's Alpha: 0.94, 0.93, 0.96, 0.45, 0.68, 0.33, 0.55, 0.79, 0.86, 0.79

# %%
from support.data_support import load_hexaco_data
from support.jaccard import calc_jaccard_with_hexaco
jaccards = calc_jaccard_with_hexaco(agent_loadings_df, load_hexaco_data())
highest_jaccards = list(zip(jaccards.index, jaccards.idxmax(axis=1), jaccards.max(axis=1)))
print("Highest Jaccard Similarities:")
[print(f" * {a} -> {b}, ({c:.3f})") for a, b, c in list(highest_jaccards)];
# Out:
# Highest Jaccard Similarities:
#  * Factor1 -> Honesty-Humility, (0.085)
#  * Factor2 -> Agreeableness, (0.106)
#  * Factor3 -> Extraversion, (0.083)
#  * Factor4 -> Conscientiousness, (0.065)
#  * Factor5 -> Emotionality, (0.024)
#  * Factor6 -> Openness, (0.047)
#  * Factor7 -> Emotionality, (0.166)
#  * Factor8 -> Emotionality, (0.048)
#  * Factor9 -> Emotionality, (0.089)
#  * Factor10 -> Honesty-Humility, (0.021)

# %%
from support.semantic_similarity import load_embedding_model, compute_similarity
model = load_embedding_model()
for i, m in enumerate(highest_loadings.keys()):
    # reduce terms to only those we know are in the model...
    ats = [x for x in highest_loadings[m].index if x in model]
    sim, matrix = compute_similarity(ats, model)
    print(f"Average similarity for {m}({labels_factors[i]}): {sim:.3f}")
# Out:
# Average similarity for Factor1(Dishonesty): 0.549
# Average similarity for Factor2(Disagreeableness): 0.529
# Average similarity for Factor3(Introversion): 0.498
# Average similarity for Factor4(Unconscientiousness): 0.459
# Average similarity for Factor5(Unheroic): 0.472
# Average similarity for Factor6(Unscholarly): 0.466
# Average similarity for Factor7(Gendered-emotionality): 0.549
# Average similarity for Factor8(Unsentimentality): 0.437
# Average similarity for Factor9(Insensitivity): 0.501
# Average similarity for Factor10(Unartistic): 0.523
