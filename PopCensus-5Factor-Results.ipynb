# %%
from results_template import generate_results

generate_results(5, 'PopCensus', 
                 'data/popc_ipsatised_results.csv', 
                 'intermediate/loadings_popc_5.csv',
                 ['Introversion', 'Assertiveness', 'Dishonesty', 
                  'Unconventionality', 'Provincial']);
# Out:
# ## Performing PCA & displaying results for PopCensus's 5 solution.
# Loadings shape = (1702, 5)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Factor1(Introversion)</th>
#       <th>Factor2(Assertiveness)</th>
#       <th>Factor3(Dishonesty)</th>
#       <th>Factor4(Unconventionality)</th>
#       <th>Factor5(Provincial)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ungregarious(0.79)</td>
#       <td>unbold(-0.77)</td>
#       <td>deceptive(0.88)</td>
#       <td>strait-laced(-0.68)</td>
#       <td>homespun(0.59)</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>distant(0.78)</td>
#       <td>placid(-0.75)</td>
#       <td>manipulative(0.88)</td>
#       <td>overrigid(-0.62)</td>
#       <td>folksy(0.57)</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>uncompanionable(0.77)</td>
#       <td>mild(-0.75)</td>
#       <td>sly(0.87)</td>
# ...
