# %%
from results_template import generate_results

generate_results(8, 'PopProfessional', 
                 'data/popp_ipsatised_results.csv', 
                 'intermediate/loadings_popp_8.csv',
                 ['Unconscientiousness', 'Introversion', 'Unconciliatory', 'Conventional', 
                  'Extravagant', 'Emotionality', 'Heroic', 'Unscholarly'])
# Out:
# ## PC & Results for PopProfessional's 8 Solution.
# Args: input_file =  data/popp_ipsatised_results.csv n_factors = 8 rotation_method = promax
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined.
# Chi square is based upon observed residuals.
# The determinant of the smoothed correlation was zero.
# This means the objective function is not defined for the null model either.
# The Chi square is thus based upon observed correlations.
# Loadings shape = (1666, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Factor1(Unconscientiousness)</th>
#       <th>Factor2(Introversion)</th>
#       <th>Factor3(Unconciliatory)</th>
#       <th>Factor4(Conventional)</th>
#       <th>Factor5(Extravagant)</th>
#       <th>Factor6(Emotionality)</th>
#       <th>Factor7(Heroic)</th>
#       <th>Factor8(Unscholarly)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...
