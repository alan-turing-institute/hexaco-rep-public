# %%
import json
import pandas as pd
from matplotlib import pyplot as plt
from support.biography_support import *

population = json.load(open('data/pop_census.json', 'r'))
responses = pd.read_csv("data/popc_results.csv", index_col=0)
responses.drop('niggardly', axis=1, inplace=True)
plot(population, responses)
